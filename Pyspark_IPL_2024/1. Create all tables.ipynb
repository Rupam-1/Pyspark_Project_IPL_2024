# %% [markdown]
# ### This script :
# ##### 1) creates all the tables required for the IPL database
# ##### 2) populates the tables with the data for the match 1 between Royal Challengers Bangalore (RCB) and Chennai Super Kings (CSK)

# %%
# Note - Always create the Parent table first then create the Child tables

# %%
# %sql
create catalog if not exists ipl_2024_project;
use catalog ipl_2024_project;
create schema if not exists SQL;
create schema if not exists PYSPARK;
use schema PYSPARK;

# %%
# Create the Venue Table
from pyspark.sql.types import (StructType, StructField, IntegerType, StringType)
venue_schema = StructType([
    StructField("venue_id", IntegerType(), False),
    StructField("venue_name", StringType(), False),
])
venue_data = [(1, "MA Chidambaram Stadium, Chepauk, Chennai")]
venue_df = spark.createDataFrame(venue_data, venue_schema)
venue_df.write.mode("overwrite").saveAsTable("venue")

# %%
# Create Team Table
from pyspark.sql.types import (StructType, StructField, IntegerType, StringType)
team_schema = StructType([
    StructField("team_id", IntegerType(), False),      # NOT NULL
    StructField("team_name", StringType(), False)      # NOT NULL
])
team_data = [
    (1, "Royal Challengers Bengaluru"),
    (2, "Chennai Super Kings")]
team_df = spark.createDataFrame(team_data, schema=team_schema)
team_df.write.mode("overwrite").saveAsTable("team")

# %%
# Create Player table
from pyspark.sql.types import (StructType, StructField, IntegerType, StringType)

player_schema = StructType([
    StructField("player_id", IntegerType(), False),
    StructField("player_name", StringType(), False),
    StructField("team_id", IntegerType(), False)])

player_data = [
    (1,'V Kohli',1),
    (2,'F du Plessis',1),
    (3,'RM Patidar',1),
    (4,'GJ Maxwell',1),
    (5,'C Green',1),
    (6,'Anuj Rawat',1),
    (7,'KD Karthik',1),
    (8,'KV Sharma',1),
    (9,'AS Joseph',1),
    (10,'Mayank Dagar',1),
    (11,'Mohammed Siraj',1),
    (12,'Yash Dayal',1),
    (13,'RD Gaikwad',2),
    (14,'R Ravindra',2),
    (15,'AM Rahane',2),
    (16,'DJ Mitchell',2),
    (17,'S Dube',2),
    (18,'RA Jadeja',2),
    (19,'Sameer Rizvi',2),
    (20,'MS Dhoni',2),
    (21,'DL Chahar',2),
    (22,'M Theekshana',2),
    (23,'TU Deshpande',2),
    (24,'Mustafizur Rahman',2)
]
player_df = spark.createDataFrame(player_data, schema=player_schema)
player_df.write.mode("overwrite").saveAsTable("player")

# %%
# Create Match table
from pyspark.sql.types import (StructType, StructField, IntegerType, StringType)
match_schema = StructType([
    StructField("match_id", IntegerType(), False),
    StructField("match_date", StringType(), False),
    StructField("venue_id", IntegerType(), False)
])
match_data = [(1, '2024-03-22', 1)]
match_df = spark.createDataFrame(match_data, schema=match_schema)
match_df.write.mode("overwrite").saveAsTable("match")

# %%
# Create Innings table
from pyspark.sql.types import (StructType, StructField, IntegerType)
innings_schema = StructType([
    StructField("match_id", IntegerType(), False),
    StructField("innings_no", IntegerType(), False),
    StructField("batting_team_id", IntegerType(), False),
    StructField("bowling_team_id", IntegerType(), False)
])
innings_data = [(1, 1, 1, 2), (1, 2, 2, 1)]
innings_df = spark.createDataFrame(innings_data, schema=innings_schema)
innings_df.write.mode("overwrite").saveAsTable("innings")

# %%
# create score_by_ball table
from pyspark.sql.types import *
score_schema = StructType([
    StructField("match_id", IntegerType(), True),
    StructField("innings_no", IntegerType(), True),
    StructField("ball_no", DoubleType(), True),
    StructField("striker_id", IntegerType(), True),
    StructField("non_striker_id", IntegerType(), True),
    StructField("bowler_id", IntegerType(), True),
    StructField("runs_off_bat", IntegerType(), True),
    StructField("extras", IntegerType(), True),
    StructField("wides", IntegerType(), True),
    StructField("noballs", IntegerType(), True),
    StructField("byes", IntegerType(), True),
    StructField("legbyes", IntegerType(), True),
    StructField("penalty", IntegerType(), True),
    StructField("wicket_type", StringType(), True),
    StructField("dismissed_player_id", IntegerType(), True)
])
score_data = [(1, 1, 0.1, 1, 2, 21, 0, 1, 1, None, None, None, None, None, None), (1, 1, 0.2, 1, 2, 21, 1, 0, None, None, None, None, None, None, None), (1, 1, 0.3, 2, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 0.4, 2, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 0.5, 2, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 0.6, 2, 1, 21, 4, 0, None, None, None, None, None, None, None), (1, 1, 0.7, 2, 1, 21, 1, 0, None, None, None, None, None, None, None), (1, 1, 1.1, 2, 1, 23, 4, 0, None, None, None, None, None, None, None), (1, 1, 1.2, 2, 1, 23, 0, 0, None, None, None, None, None, None, None), (1, 1, 1.3, 2, 1, 23, 4, 0, None, None, None, None, None, None, None), (1, 1, 1.4, 2, 1, 23, 0, 0, None, None, None, None, None, None, None), (1, 1, 1.5, 2, 1, 23, 0, 0, None, None, None, None, None, None, None), (1, 1, 1.6, 2, 1, 23, 1, 0, None, None, None, None, None, None, None), (1, 1, 2.1, 2, 1, 21, 4, 0, None, None, None, None, None, None, None), (1, 1, 2.2, 2, 1, 21, 0, 1, 1, None, None, None, None, None, None), (1, 1, 2.3, 2, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 2.4, 2, 1, 21, 4, 0, None, None, None, None, None, None, None), (1, 1, 2.5, 2, 1, 21, 4, 0, None, None, None, None, None, None, None), (1, 1, 2.6, 2, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 2.7, 2, 1, 21, 4, 0, None, None, None, None, None, None, None), (1, 1, 3.1, 1, 2, 22, 0, 0, None, None, None, None, None, None, None), (1, 1, 3.2, 1, 2, 22, 1, 0, None, None, None, None, None, None, None), (1, 1, 3.3, 2, 1, 22, 0, 0, None, None, None, None, None, None, None), (1, 1, 3.4, 2, 1, 22, 0, 1, None, None, 1, None, None, None, None), (1, 1, 3.5, 1, 2, 22, 1, 0, None, None, None, None, None, None, None), (1, 1, 3.6, 2, 1, 22, 1, 0, None, None, None, None, None, None, None), (1, 1, 4.1, 2, 1, 24, 0, 0, None, None, None, None, None, None, None), (1, 1, 4.2, 2, 1, 24, 4, 0, None, None, None, None, None, None, None), (1, 1, 4.3, 2, 1, 24, 0, 0, None, None, None, None, None, 'caught', 2), (1, 1, 4.4, 3, 1, 24, 0, 0, None, None, None, None, None, None, None), (1, 1, 4.5, 3, 1, 24, 0, 0, None, None, None, None, None, None, None), (1, 1, 4.6, 3, 1, 24, 0, 0, None, None, None, None, None, 'caught', 3), (1, 1, 5.1, 1, 4, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 5.2, 1, 4, 21, 1, 0, None, None, None, None, None, None, None), (1, 1, 5.3, 4, 1, 21, 0, 0, None, None, None, None, None, 'caught', 4), (1, 1, 5.4, 5, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 5.5, 5, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 5.6, 5, 1, 21, 0, 0, None, None, None, None, None, None, None), (1, 1, 6.1, 1, 5, 18, 1, 0, None, None, None, None, None, None, None), (1, 1,
 0, None, None, None, None, None, None, None), (1, 2, 13.6, 17, 18, 4, 0, 0, None, None, None, None, None, None, None), (1, 2, 14.1, 18, 17, 11, 2, 0, None, None, None, None, None, None, None), (1, 2, 14.2, 18, 17, 11, 2, 0, None, None, None, None, None, None, None), (1, 2, 14.3, 18, 17, 11, 1, 0, None, None, None, None, None, None, None), (1, 2, 14.4, 17, 18, 11, 1, 0, None, None, None, None, None, None, None), (1, 2, 14.5, 18, 17, 11, 1, 0, None, None, None, None, None, None, None), (1, 2, 14.6, 17, 18, 11, 0, 0, None, None, None, None, None, None, None), (1, 2, 15.1, 18, 17, 5, 1, 0, None, None, None, None, None, None, None), (1, 2, 15.2, 17, 18, 5, 4, 0, None, None, None, None, None, None, None), (1, 2, 15.3, 17, 18, 5, 0, 1, 1, None, None, None, None, None, None), (1, 2, 15.4, 17, 18, 5, 3, 0, None, None, None, None, None, None, None), (1, 2, 15.5, 18, 17, 5, 1, 0, None, None, None, None, None, None, None), (1, 2, 15.6, 17, 18, 5, 1, 0, None, None, None, None, None, None, None), (1, 2, 15.7, 18, 17, 5, 1, 0, None, None, None, None, None, None, None), (1, 2, 16.1, 18, 17, 9, 2, 0, None, None, None, None, None, None, None), (1, 2, 16.2, 18, 17, 9, 2, 0, None, None, None, None, None, None, None), (1, 2, 16.3, 18, 17, 9, 1, 0, None, None, None, None, None, None, None), (1, 2, 16.4, 17, 18, 9, 0, 1, 1, None, None, None, None, None, None), (1, 2, 16.5, 17, 18, 9, 4, 0, None, None, None, None, None, None, None), (1, 2, 16.6, 17, 18, 9, 0, 1, 1, None, None, None, None, None, None), (1, 2, 16.7, 17, 18, 9, 0, 4, None, None, 4, None, None, None, None), (1, 2, 16.8, 17, 18, 9, 1, 0, None, None, None, None, None, None, None), (1, 2, 17.1, 17, 18, 11, 0, 0, None, None, None, None, None, None, None), (1, 2, 17.2, 17, 18, 11, 4, 0, None, None, None, None, None, None, None), (1, 2, 17.3, 17, 18, 11, 0, 0, None, None, None, None, None, None, None), (1, 2, 17.4, 17, 18, 11, 0, 0, None, None, None, None, None, None, None), (1, 2, 17.5, 17, 18, 11, 4, 0, None, None, None, None, None, None, None), (1, 2, 17.6, 17, 18, 11, 0, 0, None, None, None, None, None, None, None), (1, 2, 18.1, 18, 17, 9, 1, 0, None, None, None, None, None, None, None), (1, 2, 18.2, 17, 18, 9, 0, 1, 1, None, None, None, None, None, None), (1, 2, 18.3, 17, 18, 9, 0, 0, None, None, None, None, None, None, None), (1, 2, 18.4, 17, 18, 9, 6, 0, None, None, None, None, None, None, None), (1, 2, 18.5, 17, 18, 9, 0, 4, None, None, None, 4, None, None, None)]
score_by_ball_df = spark.createDataFrame(score_data, score_schema)
score_by_ball_df.write.mode("overwrite").saveAsTable("score_by_ball")

# %%
# Create result table
from pyspark.sql.types import *
result_schema = StructType([
    StructField("match_id", IntegerType(), False),
    StructField("winning_team_id", IntegerType(), False),
    StructField("player_of_the_match_id", IntegerType(), False)
])
result_data = [(1, 2, 24)]
result_df = spark.createDataFrame(result_data, result_schema)
result_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("result")

# %%
# team_df
team_df.display()

# player_df
player_df.display()

# match_df
match_df.display()

# innings_df
innings_df.display()

# score_by_ball_df
score_by_ball_df.display()

# result_df
result_df.display()
